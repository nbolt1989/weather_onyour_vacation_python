# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint
from datetime import time

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

#Setting up my URL and query URL
# There was an issue where it was reading in metric so I converted it to imperial:
# https://openweathermap.org/current#format
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&"
# Query URL:
query_url = url + "appid=" + weather_api_key + "&q="
#requests.get(query_url + 'portland').json()

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500) 
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500) 
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(len(cities))
# Out:
# 642

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#Lists
cityname = []
cityID = []
lat = []
lng = []
maxtemp = []
humidity = [] 
cloudiness = []
windspeed = []
country = []
date = []
# Counter
record = 0

print('''
Beginning Data Retrieval
------------------------
    ''')
#Probably going to run into fetching errors so this is where we may have to do try and except
for i in cities:
    try: 
        data_loop = requests.get(query_url + i).json()
        record += 1
        cityname.append(data_loop['name'])
        cityID.append(data_loop['id'])
        lat.append(data_loop['coord']['lat'])
        lng.append(data_loop['coord']['lon'])
        maxtemp.append(data_loop['main']['temp_max'])
        humidity.append(data_loop['main']['humidity'])
        cloudiness.append(data_loop['clouds']['all'])
        windspeed.append(data_loop['wind']['speed'])
        country.append(data_loop['sys']['country'])
        date.append(data_loop['dt'])
        print(f'Processing Record {record} for the city of: {i.title()}')
        #if record > 9: #will need to set this to 50 when I run the full report
            #record = 0
    except KeyError:
        print(f'City was not found for Record {record}...skipping to next line')
print('''
-----------------------
Data Retrieval Complete
-----------------------
''')
# Out:
# Beginning Data Retrieval
# ------------------------
#
# Processing Record 1 for the city of: Aklavik
# Processing Record 2 for the city of: Yellowknife
# Processing Record 3 for the city of: Constitucion
# Processing Record 4 for the city of: Jamestown
# Processing Record 5 for the city of: Marsh Harbour
# Processing Record 6 for the city of: Mahebourg
# City was not found for Record 7...skipping to next line
# Processing Record 8 for the city of: Castro
# Processing Record 9 for the city of: Eyl
# Processing Record 10 for the city of: Qinzhou
# Processing Record 11 for the city of: Hammerfest
# City was not found for Record 12...skipping to next line
# Processing Record 13 for the city of: Puerto Ayora
# Processing Record 14 for the city of: Port Elizabeth
# Processing Record 15 for the city of: Punta Arenas
# Processing Record 16 for the city of: Ilulissat
# Processing Record 17 for the city of: Shirokiy
# Processing Record 18 for the city of: Sao Sebastiao
# Processing Record 19 for the city of: Ambulu
# Processing Record 20 for the city of: Udalguri
# Processing Record 21 for the city of: Mitsamiouli
# Processing Record 22 for the city of: Hithadhoo
# City was not found for Record 23...skipping to next line
# Processing Record 24 for the city of: Herat
# Processing Record 25 for the city of: Mar Del Plata
# Processing Record 26 for the city of: Te Anau
# Processing Record 27 for the city of: Tuy Hoa
# Processing Record 28 for the city of: Bredasdorp
# Processing Record 29 for the city of: Hilo
# Processing Record 30 for the city of: Kahului
# City was not found for Record 31...skipping to next line
# City was not found for Record 32...skipping to next line
# Processing Record 33 for the city of: Nikolskoye
# Processing Record 34 for the city of: Barrow
# Processing Record 35 for the city of: Monrovia
# Processing Record 36 for the city of: Portland
# Processing Record 37 for the city of: Cidreira
# Processing Record 38 for the city of: Port-Cartier
# Processing Record 39 for the city of: Mataura
# Processing Record 40 for the city of: Bluff
# Processing Record 631 for the city of: Stykkisholmur
# Processing Record 632 for the city of: Maceio
# Processing Record 633 for the city of: Ola
# Processing Record 634 for the city of: Leningradskiy
# Processing Record 635 for the city of: Peterhead
# Processing Record 636 for the city of: Maningrida
# Processing Record 637 for the city of: Baraki Barak
# Processing Record 638 for the city of: Petropavlovsk-Kamchatskiy
# Processing Record 639 for the city of: Soe
# Processing Record 640 for the city of: Dubrovytsya
# Processing Record 641 for the city of: Shache
# Processing Record 642 for the city of: Tessalit
#
# -----------------------
# Data Retrieval Complete
# -----------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_dict = {'City': cityname,'Lat':lat,'Long':lng,'Max Temp': maxtemp,'Humidity':humidity,\
               'Cloudiness': cloudiness, 'Wind Speed':windspeed, 'Country': country, 'Date':date}
weather_df = pd.DataFrame(weather_dict)
#Conversion of time 
#weather_df['Date']=(pd.to_datetime(weather_df['Date'],unit='s')) 
#timestamp = weather_df['Date']
#export
#weather_df.to_csv(r'Weather_DF.csv')

# %%
weather_df.head(10)
# Out:
#             City    Lat    Long  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0        Aklavik  68.22 -135.01     50.00        76          75        8.05
# 1    Yellowknife  62.46 -114.35     70.00        52          20        6.93
# 2   Constitución -35.33  -72.42     49.37        78          80        6.13
# 3      Jamestown  42.10  -79.24     72.00        88          90        3.36
# 4  Marsh Harbour  26.54  -77.06     84.65        75         100       13.80
# 5      Mahébourg -20.41   57.70     68.00        68          40       17.22
# 6         Castro -24.79  -50.01     51.55        89           0        4.07
# 7            Eyl   7.98   49.82     80.46        62          13       28.70
# 8        Qinzhou  21.95  108.62     89.80        67         100       22.44
# 9     Hammerfest  70.66   23.68     46.40        93          75       16.11
#
#   Country        Date
# 0      CA  07/11/2020
# 1      CA  07/11/2020
# 2      CL  07/11/2020
# 3      US  07/11/2020
# 4      BS  07/11/2020
# 5      MU  07/11/2020
# 6      BR  07/11/2020
# 7      SO  07/11/2020
# 8      CN  07/11/2020
# 9      NO  07/11/2020

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.
highumid = weather_df.loc[(weather_df['Humidity']>100)]
highumid
# Out:
# Empty DataFrame
# Columns: [City, Lat, Long, Max Temp, Humidity, Cloudiness, Wind Speed, Country, Date]
# Index: []

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
# clean_city_data =

# %%
# Extract relevant fields from the data frame
# Export the City_Data into a csv

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# x axis is lat and y = max temp in F 
date = ('07/11/2020')
x_axis = weather_df['Lat']
y_axis = weather_df['Max Temp']
plt.scatter(x_axis, y_axis)
#plot.scatter(kind="scatter", x="Latitude", y="Max Temp", grid=False, figsize=(6,5),
             # title="Testing")
# label
plt.xlabel("Latitude")
plt.ylabel("Max Temp in F")
plt.title("Max Temp by Latitude " + date )
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# x axis is lat and y = max temp in F 
x_axis2 = weather_df['Lat']
y_axis2 = weather_df['Humidity']
plt.scatter(x_axis2, y_axis2)
#plot.scatter(kind="scatter", x="Latitude", y="Max Temp", grid=False, figsize=(6,5),
             # title="Testing")
# label
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.title("Humidity by Latitude " + date )
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# x axis is lat and y = max temp in F 
x_axis3 = weather_df['Lat']
y_axis3 = weather_df['Cloudiness']
plt.scatter(x_axis3, y_axis3)
#plot.scatter(kind="scatter", x="Latitude", y="Max Temp", grid=False, figsize=(6,5),
             # title="Testing")
# label
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.title("Cloudiness by Latitude " + date )
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# x axis is lat and y = max temp in F 
x_axis4 = weather_df['Lat']
y_axis4 = weather_df['Wind Speed']
plt.scatter(x_axis4, y_axis4)
#plot.scatter(kind="scatter", x="Latitude", y="Max Temp", grid=False, figsize=(6,5),
             # title="Testing")
# label
plt.xlabel("Latitude")
plt.ylabel("Windspeed (mph)")
plt.title("Windspeed by Latitude " + date )
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots
# My function will loop through my lists so I can call the function for whatever my two variables are for the x
# and y axis. I will then call the function in a loop of the list.

# %%
#x_values = weather_df['Lat']
#y_values = weather_df['Wind Speed']

def linfunct(x_values, y_values,title,xlabel,ylabel,i,l):
    #Stats will call from my variable above and then look for what ever argument I establish in ()
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    #plot and format
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"red")
    plt.annotate(line_eq,(i,l), fontsize=10,color="red")
    print(f'The correlation coefficient: {rvalue}')
    #label
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.title(title)
    plt.show()

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_df = weather_df.loc[(weather_df['Lat']>0.01)]
southern_df = weather_df.loc[(weather_df['Lat']<0)]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
linfunct(northern_df["Lat"],northern_df['Max Temp'],\
         title="Northern Hem: Max Temp by Latitude",xlabel = "Latitude", ylabel = "Max Temp (F)", i=30,l=50)
# Out:
# The correlation coefficient: -0.6956541340116741

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
linfunct(southern_df['Lat'],southern_df['Max Temp']\
         ,title="Southern Hem: Max Temp by Latitude",xlabel = "Latitude", ylabel = "Max Temp (F)",i=-40,l=80)
# Out:
# The correlation coefficient: 0.7371433820905701

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
linfunct(northern_df['Lat'],northern_df['Humidity'],\
         title="Northern Hem: Humidity by Latitude",xlabel = "Latitude", ylabel = "Humidity", i=60,l=20)
# Out:
# The correlation coefficient: -0.06992473864370184

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
linfunct(southern_df['Lat'],southern_df['Humidity'],title="Southern Hem: Humidity by Latitude",\
         xlabel = "Latitude", ylabel = "Humidity", i=-50,l=60)
# Out:
# The correlation coefficient: 0.14052261732719087

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
linfunct(northern_df['Lat'],northern_df['Cloudiness'],title="Northern Hem: CLoudiness by Latitude",\
         xlabel = "Latitude", ylabel = "Cloudiness", i=30,l=60)
# Out:
# The correlation coefficient: -0.11891745436666429

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
linfunct(southern_df['Lat'],southern_df['Cloudiness'],title="Southern Hem: Cloudiness by Latitude",\
         xlabel = "Latitude", ylabel = "Cloudiness",i=-40,l=50)
# Out:
# The correlation coefficient: 0.054309381402276785

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
linfunct(northern_df['Lat'],northern_df['Wind Speed'],title="Northern Hem: Wind Speed (mph) by Latitude",\
         xlabel = "Latitude", ylabel = "Wind Speed(mph)", i=50,l=25)
# Out:
# The correlation coefficient: -0.04406661991535867

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
linfunct(southern_df['Lat'],southern_df['Wind Speed'],title="Southern Hem: Wind Speed (mph) by Latitude",\
         xlabel = "Latitude", ylabel = "Wind Speed (mph)",i=-40,l=20)
# Out:
# The correlation coefficient: -0.182718947285538
